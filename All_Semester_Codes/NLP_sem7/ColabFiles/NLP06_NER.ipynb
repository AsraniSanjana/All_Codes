# %% [markdown]
# <a href="https://colab.research.google.com/github/AsraniSanjana/All_Codes/blob/main/All_Semester_Codes/NLP_sem7/ColabFiles/NLP06_NER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **NAME**: SANJANA ASRANI
#
# **DIV**:D17B
#
# **ROLL NO**.: 01
#
# **NLP LAB 06**: IMPLEMENT A NAMED ENTITY RECOGNIZER FOR THE GIVREN INPUT. ( DOMAIN-SPECIFIC EXAMPLE-BANK, POLITICAL NEWS, TOURISM)

# %% [markdown]
# # **NER**
# Entity types:
#
#
# ![image.png](data:image/png;base64,...)
#
#
# Numerical Expressions:
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Who uses NER?**
# Various industries and applications use NER in different ways:
# ● Chatbots: OpenAI's generative AI, ChatGPT, Google's Bard and other chatbots use NER models to identify relevant entities mentioned in user queries and conversations. This helps them understand the context of a user's question and improves their responses.
# ● HR: These systems can streamline recruitment and hiring by summarizing applicants' resumes and extracting information, such as qualifications, education and references. NER can also filter employee complaints and queries to the relevant departments, helping to organize internal workflows.
# ● News providers: News providers use NER to analyze the many articles and social media posts they need to review and to categorize the content into important information and trends. This helps them quickly understand and report on news and current events.
# ● Recommendation engines: Many companies use NER to improve the relevancy of their recommendation engines. For instance, companies like Netflix use NER to analyze users' searches and viewing histories to provide personalized recommendations.
#
# # **NER challenges**
# NER also comes with its own set of issues:
# ● Has difficulty in analyzing lexical ambiguities, semantics and evolving usages of language in text.
# ● Runs into problems with spelling variations.
# ● Doesn't know all foreign words.
# ● Can have issues with spoken word text, such as telephone conversations. ● Leads to many state-of-the-art NER models reporting limited performance measures.
# ● Can require large volumes of training data or a lot of human intervention. ● Can be prone to bias in results if the ML algorithm has hidden bias.

# %%
import spacy
from spacy import displacy

# %%
NER = spacy.load("en_core_web_sm")

# %%
#Hello, I am Sanjana Asrani, A 4th year student studying in VESIT, an enginnering college in mumbai. My aggregate percentage upto semester 5 is 91.14%. Today is September 28, 2023
raw_text=input()
# Out:
# Hello, I am Sanjana Asrani, A 4th year student studying in VESIT, an enginnering college in mumbai. My aggregate percentage upto semester 5 is 91.14%. Today is September 28, 2023

# %%
text1=NER(raw_text)

# %%
for word in text1.ents:
    print(word.text,word.label_)
# Out:
# Sanjana Asrani PERSON
# 4th ORDINAL
# mumbai GPE
# 91.14% PERCENT
# Today DATE
# September 28, 2023 DATE

# %%
spacy.explain("ORG")
# Out:
# 'Companies, agencies, institutions, etc.'

# %%
spacy.explain("GPE")
# Out:
# 'Countries, cities, states'

# %%
spacy.explain("DATE")
# Out:
# 'Absolute or relative dates or periods'

# %%
spacy.explain("CARDINAL")
# Out:
# 'Numerals that do not fall under another type'

# %%
spacy.explain("MONEY")
# Out:
# 'Monetary values, including unit'

# %%
spacy.explain("PERSON")
# Out:
# 'People, including fictional'

# %%
displacy.render(text1,style="ent",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Hello, I am
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sanjana Asrani
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , A
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  year student studying in VESIT, an enginnering college in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mumbai
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . My aggregate percentage upto semester 5 is
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     91.14%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
# .
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  is
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     September 28, 2023
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </div></span>

# %% [markdown]
# # **CONCLUSION**:
# In conclusion, the word cloud experiment effectively summarized and visually represented key terms from the text. It provided a quick, **
# engaging overview of word frequency and helped identify prominent themes, making it a valuable tool for turning text data into a visually appealing and informative representation that can be easily
# understood at a glance. .
